# %% [markdown]
# # Datasets: Environmental Covariates

# %% [markdown]
# Datasets listed in [Supplementary_Data_File_1._environmental_covariates - Google Sheet](https://docs.google.com/spreadsheets/d/1hPw9G1A34SnlbDJ8sk3LYfwgoLN0Gbail2xdNb7viGc/edit#gid=106509025).

# %%
import os, sys, io, subprocess
from tqdm import tqdm
from pathlib import Path
import shutil
from urlpath import URL
import math
import numpy as np
import pandas as pd
import xarray as xr
import rioxarray

# %%
Path.ls = lambda p: list(p.iterdir())

def _cp(src, dst):
    assert src.is_file()
    shutil.copy(src, dst)

# %%
def check_id(data_id):
    if data_id in DATA_SRC:
        print(f'Data_id "{data_id}" already exists. '
              'Check that it is not re-used.')
        raise    

        
def add_download(id, download):
    ENCOV = ENCOV.append(
        {'id':id, 'download':URL(download)}, ignore_index=True)

    
def add_filename(id, filename):
    ENCOV = ENCOV.append(
        {'id':id, 'filename':filename}, ignore_index=True)

# %%
def execute_wgt(url, dst='./'):
    cmd = ['wget', url, '-O', Path(dst)/url.name]
    proc = subprocess.Popen(cmd, stderr=subprocess.PIPE)
    return proc


# def monitor_wgt_proc(proc):
#     while True:
#         line = proc.stderr.readline()

#         if line=='' and proc.poll() is not None:
#             break
#         else:
#             print(f'\r{line}', end='')
     
#     proc.stderr.close()
    
#     return_code = proc.wait()
#     return return_code

# %%
def unzip(src, dst='./'):
    '''
    Unpack zip file at `src` to directory `dst`.
    '''
    dst.mkdir(exist_ok=True)
    proc = subprocess.Popen(
        ['unzip', str(src), '-d', str(dst)], 
        stdout=subprocess.PIPE, stderr=subprocess.PIPE)
    return proc

# %%
DIR_DATA = Path('../data')

# %%
# load Google Sheet for data sources and info

pth_csv = DIR_DATA / ('Supplementary_Data_File_1.'
                      '_environmental_covariates - sheet1.csv')

ENCOV = pd.read_csv(pth_csv)

# %%
ENCOV.columns
# Out:
# Index(['#', 'Variable', 'Description', 'Source / Link', 'doi',
#        'File Size (GB)', 'GEE ID', 'Unnamed: 7'],
#       dtype='object')

# %% [markdown]
# ## Earthenv Cloud
# Global 1-km Cloud Cover: https://www.earthenv.org/cloud

# %%
var_downloads = [
    ('EarthEnvCloudCover_MODCF_interannualSD', 
    'https://data.earthenv.org/cloud/MODCF_interannualSD.tif'),

    ('EarthEnvCloudCover_MODCF_intraannualSD',
    'https://data.earthenv.org/cloud/MODCF_intraannualSD.tif'),

    ('EarthEnvCloudCover_MODCF_meanannual',
    'https://data.earthenv.org/cloud/MODCF_meanannual.tif'),

    ('EarthEnvCloudCover_MODCF_seasonality_concentration',
    'https://data.earthenv.org/cloud/'
     'MODCF_seasonality_concentration.tif'),

    ('EarthEnvCloudCover_MODCF_seasonality_theta',
    'https://data.earthenv.org/cloud/MODCF_seasonality_theta.tif'),
]

# %%
for variable, download in var_downloads:
    ENCOV.loc[ENCOV.Variable==variable, 'Source / Link'] = download

# %% [markdown]
# ## Earthenv Topography
#
# Global 1,5,10,100-km Topography: https://www.earthenv.org/topography.

# %% [markdown]
# Couldn't obtain the direct download URLs for these using the browser's developer tools.

# %%
var_fns = [
    ('EarthEnvTopoMed_1stOrderPartialDerivEW',
     'dx_1KMmd_GMTEDmd.tif'),
    
    ('EarthEnvTopoMed_1stOrderPartialDerivNS', 
     'dy_1KMmd_GMTEDmd.tif'),

    ('EarthEnvTopoMed_2ndOrderPartialDerivEW',
     'dxx_1KMmd_GMTEDmd.tif'),

    ('EarthEnvTopoMed_2ndOrderPartialDerivNS',
     'dyy_1KMmd_GMTEDmd.tif'),

    ('EarthEnvTopoMed_AspectCosine',
     'aspectcosine_1KMmd_GMTEDmd.tif'),

    ('EarthEnvTopoMed_AspectSine',
     'aspectsine_1KMmd_GMTEDmd.tif'),

    ('EarthEnvTopoMed_Eastness',
     'eastness_1KMmd_GMTEDmd.tif'),

    ('EarthEnvTopoMed_Elevation', 
     'elevation_1KMmd_GMTEDmd.tif'),

    ('EarthEnvTopoMed_Northness',
     'northness_1KMmd_GMTEDmd.tif'),

    ('EarthEnvTopoMed_ProfileCurvature',
     'pcurv_1KMmd_GMTEDmd.tif'),

    ('EarthEnvTopoMed_Roughness',
     'roughness_1KMmd_GMTEDmd.tif'),

    ('EarthEnvTopoMed_Slope',
     'slope_1KMmd_GMTEDmd.tif'),

    ('EarthEnvTopoMed_TangentialCurvature',
     'tcurv_1KMmd_GMTEDmd.tif'),

    ('EarthEnvTopoMed_TerrainRuggednessIndex',
     'tri_1KMmd_GMTEDmd.tif'),

    ('EarthEnvTopoMed_TopoPositionIndex',
     'tpi_1KMmd_GMTEDmd.tif'),

    ('EarthEnvTopoMed_VectorRuggednessMeasure', 
     'vrm_1KMmd_GMTEDmd.tif')
]

# %%
for variable, filename in var_fns:
    ENCOV.loc[ENCOV.Variable==variable, 'filename'] = filename

# %% [markdown]
# After uploading to GEE by user `bingosaucer`, say, set `gee_id`:

# %%
gee_user = 'bingosaucer'

# %%
is_topo = ENCOV.Variable.apply(lambda o: str(o).startswith('EarthEnvTopoMed'))

# %%
ENCOV.loc[is_topo, 'GEE ID'] = (
    ENCOV.loc[is_topo, 'Variable'].apply(
        lambda var: f'users/{gee_user}/{var}')
)

# %% [markdown]
# ## FanEtAl_Depth_to_Water_Table_AnnualMean

# %% [markdown]
# http://thredds-gfnl.usc.es/thredds/catalog/GLOBALWTDFTP/catalog.html

# %%
var_wtb = 'FanEtAl_Depth_to_Water_Table_AnnualMean'

# %%
var_downloads = [
    ('NAMERICA_WTD_annualmean', 
     'http://thredds-gfnl.usc.es/thredds/fileServer/'
     'GLOBALWTDFTP/annualmeans/NAMERICA_WTD_annualmean.nc'),
    
    ('SAMERICA_WTD_annualmean', 
     'http://thredds-gfnl.usc.es/thredds/fileServer/'
     'GLOBALWTDFTP/annualmeans/SAMERICA_WTD_annualmean.nc'),
    
    ('OCEANA_WTD_annualmean', 
     'http://thredds-gfnl.usc.es/thredds/fileServer/'
     'GLOBALWTDFTP/annualmeans/OCEANA_WTD_annualmean.nc'),
    
    ('EURASIA_WTD_annualmean', 
     'http://thredds-gfnl.usc.es/thredds/fileServer/'
     'GLOBALWTDFTP/annualmeans/EURASIA_WTD_annualmean.nc'),
    
    ('AFRICA_WTD_annualmean', 
     'http://thredds-gfnl.usc.es/thredds/fileServer/'
     'GLOBALWTDFTP/annualmeans/AFRICA_WTD_annualmean.nc'),
]

# %%
ENCOV.columns
# Out:
# Index(['#', 'Variable', 'Description', 'Source / Link', 'doi',
#        'File Size (GB)', 'GEE ID', 'Unnamed: 7', 'filename'],
#       dtype='object')

# %%
dict_wtb = ENCOV[ENCOV.Variable==var_wtb].squeeze().to_dict()

# %%
for variable, download in var_downloads:
    d = dict_wtb.copy()
    d.update(
        {'Variable': variable, 
         'Source / Link': download})
    print(d, end='\n\n')
# Out:
# {'#': 26.0, 'Variable': 'NAMERICA_WTD_annualmean', 'Description': 'Mean annual depth of the water table on the terrestrial land surface (in m below land surface)', 'Source / Link': 'http://thredds-gfnl.usc.es/thredds/fileServer/GLOBALWTDFTP/annualmeans/NAMERICA_WTD_annualmean.nc', 'doi': '10.1126/science.1229881', 'File Size (GB)': 0.09, 'GEE ID': 'users/bingosaucer/FanEtAl_Depth_to_Water_Table_AnnualMean', 'Unnamed: 7': nan, 'filename': nan}
#
# {'#': 26.0, 'Variable': 'SAMERICA_WTD_annualmean', 'Description': 'Mean annual depth of the water table on the terrestrial land surface (in m below land surface)', 'Source / Link': 'http://thredds-gfnl.usc.es/thredds/fileServer/GLOBALWTDFTP/annualmeans/SAMERICA_WTD_annualmean.nc', 'doi': '10.1126/science.1229881', 'File Size (GB)': 0.09, 'GEE ID': 'users/bingosaucer/FanEtAl_Depth_to_Water_Table_AnnualMean', 'Unnamed: 7': nan, 'filename': nan}
#
# {'#': 26.0, 'Variable': 'OCEANA_WTD_annualmean', 'Description': 'Mean annual depth of the water table on the terrestrial land surface (in m below land surface)', 'Source / Link': 'http://thredds-gfnl.usc.es/thredds/fileServer/GLOBALWTDFTP/annualmeans/OCEANA_WTD_annualmean.nc', 'doi': '10.1126/science.1229881', 'File Size (GB)': 0.09, 'GEE ID': 'users/bingosaucer/FanEtAl_Depth_to_Water_Table_AnnualMean', 'Unnamed: 7': nan, 'filename': nan}
#
# {'#': 26.0, 'Variable': 'EURASIA_WTD_annualmean', 'Description': 'Mean annual depth of the water table on the terrestrial land surface (in m below land surface)', 'Source / Link': 'http://thredds-gfnl.usc.es/thredds/fileServer/GLOBALWTDFTP/annualmeans/EURASIA_WTD_annualmean.nc', 'doi': '10.1126/science.1229881', 'File Size (GB)': 0.09, 'GEE ID': 'users/bingosaucer/FanEtAl_Depth_to_Water_Table_AnnualMean', 'Unnamed: 7': nan, 'filename': nan}
#
# {'#': 26.0, 'Variable': 'AFRICA_WTD_annualmean', 'Description': 'Mean annual depth of the water table on the terrestrial land surface (in m below land surface)', 'Source / Link': 'http://thredds-gfnl.usc.es/thredds/fileServer/GLOBALWTDFTP/annualmeans/AFRICA_WTD_annualmean.nc', 'doi': '10.1126/science.1229881', 'File Size (GB)': 0.09, 'GEE ID': 'users/bingosaucer/FanEtAl_Depth_to_Water_Table_AnnualMean', 'Unnamed: 7': nan, 'filename': nan}

# %%
# %%time

ds = rioxarray.open_rasterio(f'../data/{url.name}')
ds.rio.write_crs('epsg:4326', inplace=True)
ds = ds.squeeze()
# Out:
# CPU times: user 131 ms, sys: 43.4 ms, total: 174 ms
# Wall time: 280 ms

# %%
ds.rio.crs
# Out:
# CRS.from_epsg(4326)

# %%
# %%time

# ds.WTD.rio.to_raster(f'../data/{url.stem}.tiff')
ds.WTD.rio.to_raster(f'../data/NAMERICA_WTD_annualmean.tiff')
# Out:
# CPU times: user 21min 11s, sys: 3min 35s, total: 24min 47s
# Wall time: 25min 59s

# %%
xr.open_rasterio('../data/FanEtAl_Depth_to_Water_Table_AnnualMean.tiff')
# Out:
# <xarray.DataArray (band: 1, y: 9480, x: 15360)>
# [145612800 values with dtype=int16]
# Coordinates:
#   * band     (band) int64 1
#   * y        (y) float64 84.0 83.99 83.98 83.97 ... 5.029 5.021 5.012 5.004
#   * x        (x) float64 -180.0 -180.0 -180.0 -180.0 ... -52.02 -52.01 -52.0
# Attributes:
#     transform:      (0.008333300184369964, 0.0, -180.0000010006781, 0.0, -0.0...
#     crs:            +init=epsg:4326
#     res:            (0.008333300184369964, 0.008333300447549506)
#     is_tiled:       0
#     nodatavals:     (-32767.0,)
#     scales:         (0.015259021896696421,)
#     offsets:        (-499.99237048905167,)
#     descriptions:   ('WTD',)
#     AREA_OR_POINT:  Area
#     comment:        annual mean
#     description:    water table depth
#     grid_mapping:   spatial_ref
#     units:          m

# %% [markdown]
# ## MODIS_LAI

# %% [markdown]
# https://explorer.earthengine.google.com/#detail/MODIS%2F006%2FMCD15A3H

# %% [markdown]
# ## ISRIC Data
# ISRIC World Soil Information.
# Data Hub: https://data.isric.org/geonetwork/srv/eng/catalog.search#/home

# %% [markdown]
# ## WCS_Human_Footprint_2009
# > Human Footprint 2009

# %% [markdown]
# http://wcshumanfootprint.org/

# %% [markdown]
# ### Full dataset

# %% [markdown]
# How to unpack full dataset download:
# ```
# $ unzip doi_10.5061_dryad.052q5__v2.zip
# $ brew install p7zip
# $ 7za x HumanFootprintv2.7z
# ```

# %%
path = '../data/Dryadv3/Maps'
ns = [f'{path}/{n}' for n in os.listdir(path) if n.endswith('.tif')]
sum([os.path.getsize(n) for n in ns]) / 1e9
# Out:
# 3.296027813

# %%
# %%time

da_fullset = xr.open_rasterio(
    '../data/Dryadv3/Maps/HFP2009.tif', chunks={'x':10, 'y':10})
# Out:
# CPU times: user 15.5 s, sys: 37.4 s, total: 53 s
# Wall time: 1min 8s

# %%
# %%time

(da_fullset - da).sum()
# Out:
# CPU times: user 34.3 s, sys: 47.6 s, total: 1min 21s
# Wall time: 1min 36s

# %% [markdown]
# ###  Summary 2009

# %% [markdown]
# ##  WorldClim2
#
# https://www.worldclim.org/data/index.html

# %%
def worldclim2_histdata_src():
    '''
    WorldClim v2.1 historical climate data found at:
    https://www.worldclim.org/data/worldclim21.html
    '''
    d = {}
    
    d['minimum temperature'] = {
        'download':
        URL('http://biogeo.ucdavis.edu/data/worldclim/v2.1/base/'
            'wc2.1_30s_tmin.zip'),
        'units': 'C'}
    
    d['maximum temperature'] = {
        'download':
        URL('http://biogeo.ucdavis.edu/data/worldclim/v2.1/base/'
            'wc2.1_30s_tmax.zip'),
        'units': 'C'}

    d['average temperature'] = {
        'download': 
        URL('http://biogeo.ucdavis.edu/data/worldclim/v2.1/base/'
            'wc2.1_30s_tavg.zip'),
        'units': 'C'}
    
    d['precipitation'] = {
        'download':
        URL('http://biogeo.ucdavis.edu/data/worldclim/v2.1/base/'
            'wc2.1_30s_prec.zip'),
        'units': 'mm'}
    
    d['solar radiation'] = {
        'download':
        URL('http://biogeo.ucdavis.edu/data/worldclim/v2.1/base/'
            'wc2.1_30s_srad.zip'),
        'units': 'kJ m^-2 day^-1'}
    
    d['wind speed'] = {
        'download':
        URL('http://biogeo.ucdavis.edu/data/worldclim/v2.1/base/'
            'wc2.1_30s_wind.zip'),
        'units': 'm s^-1'}
    
    d['water vapor pressure'] = {
        'download':
        URL('http://biogeo.ucdavis.edu/data/worldclim/v2.1/base/'
            'wc2.1_30s_vapr.zip'), 
        'units': 'kPa'}
    
    return d

WORLDCLIM2 = worldclim2_histdata_src()

# %% [markdown]
# Download a couple of variables.

# %%
vns = ['wind speed', 'water vapor pressure']

urls = [WORLDCLIM2[vn]['download'] for vn in vns]

procs = [execute_wgt(url, dst=DIR_DATA) for url in urls]

# %% [markdown]
# Unpack a variable and set it up for GEE.

# %%
vn = 'water vapor pressure'

collection_id = 'WorldClim2_' + '_'.join(vn.split())
collection_download = WORLD_CLIM2_SRC[vn]['download']

pth_zip = DIR_DATA / collection_download.name
dir_unzip = DIR_DATA / collection_id

# proc = unzip(pth_zip, dir_unzip)

# %%
fns = [n.name for n in dir_unzip.ls() if n.name.endswith('.tif')]
months = [n.split('.')[1].split('_')[-1] for n in fns]
asset_ids = [f'{collection_id}_{m}' for m in months]

# %% [markdown]
# Register the Image Collection.

# %%
ENCOV = ENCOV.append(
    {'id': collection_id, 'download': collection_download}, 
    ignore_index=True)

# %% [markdown]
# Register Images.

# %%
ENCOV = ENCOV.append(
    pd.DataFrame({'id': asset_ids, 'filename': fns}))

ENCOV.loc[ENCOV.id.isin(asset_ids), 
          'download'] = collection_download

# %% [markdown]
# Create the Image Collection in GEE (in the browser).

# %% [markdown]
# Set `gee_user` for the collection and individual assets.

# %%
ENCOV.loc[ENCOV.id.isin(asset_ids), 'gee_user'] = 'bingosaucer'

# %%
ENCOV.to_csv('../data/Supplementary_Data_File_1._environmental_covariates - sheet1.csv', index=False)

# %% [markdown]
# ## GEE Access Control List

# %% [markdown]
# Sets all assets to be public.

# %%
for _, r in tqdm(available.iterrows()):
    try:
        subprocess.check_call(
            ['earthengine', 'acl', 'set', 'public',
             f'users/{r.gee_user}/{r.id}'])
    except subprocess.CalledProcessError:
        continue
# Out:
# 28it [02:44,  5.88s/it]

# %% [markdown]
# # Google Earth Engine Access

# %% [markdown]
# Available

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', None)
ENCOV[ENCOV['GEE ID'].notnull()][['Variable', 'GEE ID', 'Description']]
# Out:
#                                                Variable  \
# 4                EarthEnvCloudCover_MODCF_interannualSD
# 5                EarthEnvCloudCover_MODCF_intraannualSD
# 9                EarthEnvTopoMed_1stOrderPartialDerivEW
# 10               EarthEnvTopoMed_1stOrderPartialDerivNS
# 11               EarthEnvTopoMed_2ndOrderPartialDerivEW
# 12               EarthEnvTopoMed_2ndOrderPartialDerivNS
# 13                         EarthEnvTopoMed_AspectCosine
# 14                           EarthEnvTopoMed_AspectSine
# 15                             EarthEnvTopoMed_Eastness
# 16                            EarthEnvTopoMed_Elevation
# 17                            EarthEnvTopoMed_Northness
# 18                     EarthEnvTopoMed_ProfileCurvature
# 19                            EarthEnvTopoMed_Roughness
# 20                                EarthEnvTopoMed_Slope
# 21                  EarthEnvTopoMed_TangentialCurvature
# 22               EarthEnvTopoMed_TerrainRuggednessIndex
# 23                    EarthEnvTopoMed_TopoPositionIndex
# 24              EarthEnvTopoMed_VectorRuggednessMeasure
# 25              FanEtAl_Depth_to_Water_Table_AnnualMean
# 27                                            MODIS_LAI
# 28                                           MODIS_NDVI
# 29                         SG_Absolute_depth_to_bedrock
# 30                                SG_Bulk_density_000cm
# 31                                SG_Bulk_density_005cm
# 32                                SG_Bulk_density_015cm
# 33                                SG_Bulk_density_030cm
# 34                                SG_Bulk_density_060cm
# 35                                SG_Bulk_density_100cm
# 36                                SG_Bulk_density_200cm
# 37                                         SG_CEC_000cm
# 38                                         SG_CEC_005cm
# 39                                         SG_CEC_015cm
# 40                                         SG_CEC_030cm
# 41                                         SG_CEC_060cm
# 42                                         SG_CEC_100cm
# 43                                         SG_CEC_200cm
# 44                                SG_Clay_Content_000cm
# 45                                SG_Clay_Content_005cm
# 46                                SG_Clay_Content_015cm
# 47                                SG_Clay_Content_030cm
# 48                                SG_Clay_Content_060cm
# 49                                SG_Clay_Content_100cm
# 50                                SG_Clay_Content_200cm
# 51                            SG_Coarse_fragments_000cm
# 52                            SG_Coarse_fragments_005cm
# 53                            SG_Coarse_fragments_015cm
# 54                            SG_Coarse_fragments_030cm
# 55                            SG_Coarse_fragments_060cm
# 56                            SG_Coarse_fragments_100cm
# 57                            SG_Coarse_fragments_200cm
# 58                                  SG_Depth_to_bedrock
# 59                                SG_H2O_Capacity_000cm
# 60                                SG_H2O_Capacity_005cm
# 61                                SG_H2O_Capacity_015cm
# 62                                SG_H2O_Capacity_030cm
# 63                                SG_H2O_Capacity_060cm
# 64                                SG_H2O_Capacity_100cm
# 65                                SG_H2O_Capacity_200cm
# 66                  SG_Probability_occurrence_R_horizon
# 67                                SG_Sand_Content_000cm
# 68                                SG_Sand_Content_005cm
# 69                                SG_Sand_Content_015cm
# 70                                SG_Sand_Content_030cm
# 71                                SG_Sand_Content_060cm
# 72                                SG_Sand_Content_100cm
# 73                                SG_Sand_Content_200cm
# 74                       SG_Saturated_H2O_Content_000cm
# 75                       SG_Saturated_H2O_Content_005cm
# 76                       SG_Saturated_H2O_Content_015cm
# 77                       SG_Saturated_H2O_Content_030cm
# 78                       SG_Saturated_H2O_Content_060cm
# 79                       SG_Saturated_H2O_Content_100cm
# 80                       SG_Saturated_H2O_Content_200cm
# 81                                SG_Silt_Content_000cm
# 82                                SG_Silt_Content_005cm
# 83                                SG_Silt_Content_015cm
# 84                                SG_Silt_Content_030cm
# 85                                SG_Silt_Content_060cm
# 86                                SG_Silt_Content_100cm
# 87                                SG_Silt_Content_200cm
# 88                                 SG_SOC_Content_000cm
# 89                                 SG_SOC_Content_005cm
# 90                                 SG_SOC_Content_015cm
# 91                                 SG_SOC_Content_030cm
# 92                                 SG_SOC_Content_060cm
# 93                                 SG_SOC_Content_100cm
# 94                                 SG_SOC_Content_200cm
# 95                                 SG_SOC_Density_000cm
# 96                                 SG_SOC_Density_005cm
# 97                                 SG_SOC_Density_015cm
# 98                                 SG_SOC_Density_030cm
# 99                                 SG_SOC_Density_060cm
# 100                                SG_SOC_Density_100cm
# 101                                SG_SOC_Density_200cm
# 102                         SG_SOC_Stock_000cm_to_005cm
# 103                         SG_SOC_Stock_005cm_to_015cm
# 104                         SG_SOC_Stock_015cm_to_030cm
# 105                         SG_SOC_Stock_030cm_to_060cm
# 106                         SG_SOC_Stock_060cm_to_100cm
# 107                         SG_SOC_Stock_100cm_to_200cm
# 108                    SG_Soil_H2O_Capacity_pF_20_000cm
# 109                    SG_Soil_H2O_Capacity_pF_20_005cm
# 110                    SG_Soil_H2O_Capacity_pF_20_015cm
# 111                    SG_Soil_H2O_Capacity_pF_20_030cm
# 112                    SG_Soil_H2O_Capacity_pF_20_060cm
# 113                    SG_Soil_H2O_Capacity_pF_20_100cm
# 114                    SG_Soil_H2O_Capacity_pF_20_200cm
# 115                    SG_Soil_H2O_Capacity_pF_23_000cm
# 116                    SG_Soil_H2O_Capacity_pF_23_005cm
# 117                    SG_Soil_H2O_Capacity_pF_23_015cm
# 118                    SG_Soil_H2O_Capacity_pF_23_030cm
# 119                    SG_Soil_H2O_Capacity_pF_23_060cm
# 120                    SG_Soil_H2O_Capacity_pF_23_100cm
# 121                    SG_Soil_H2O_Capacity_pF_23_200cm
# 122                    SG_Soil_H2O_Capacity_pF_25_000cm
# 123                    SG_Soil_H2O_Capacity_pF_25_005cm
# 124                    SG_Soil_H2O_Capacity_pF_25_015cm
# 125                    SG_Soil_H2O_Capacity_pF_25_030cm
# 126                    SG_Soil_H2O_Capacity_pF_25_060cm
# 127                    SG_Soil_H2O_Capacity_pF_25_100cm
# 128                    SG_Soil_H2O_Capacity_pF_25_200cm
# 129                            WCS_Human_Footprint_2009
# 130              WorldClim2_BIO_Annual_Mean_Temperature
# 131                   WorldClim2_BIO_Mean_Diurnal_Range
# 132                        WorldClim2_BIO_Isothermality
# 133              WorldClim2_BIO_Temperature_Seasonality
# 134     WorldClim2_BIO_Max_Temperature_of_Warmest_Month
# 135     WorldClim2_BIO_Min_Temperature_of_Coldest_Month
# 136             WorldClim2_BIO_Temperature_Annual_Range
# 137  WorldClim2_BIO_Mean_Temperature_of_Wettest_Quarter
# 138   WorldClim2_BIO_Mean_Temperature_of_Driest_Quarter
# 139  WorldClim2_BIO_Mean_Temperature_of_Warmest_Quarter
# 140  WorldClim2_BIO_Mean_Temperature_of_Coldest_Quarter
# 141                 WorldClim2_BIO_Annual_Precipitation
# 142       WorldClim2_BIO_Precipitation_of_Wettest_Month
# 143        WorldClim2_BIO_Precipitation_of_Driest_Month
# 144            WorldClim2_BIO_Precipitation_Seasonality
# 145     WorldClim2_BIO_Precipitation_of_Wettest_Quarter
# 146      WorldClim2_BIO_Precipitation_of_Driest_Quarter
# 147     WorldClim2_BIO_Precipitation_of_Warmest_Quarter
# 148     WorldClim2_BIO_Precipitation_of_Coldest_Quarter
# 149              WorldClim2_H2OVaporPressure_AnnualMean
# 150                WorldClim2_SolarRadiation_AnnualMean
# 151                     WorldClim2_WindSpeed_AnnualMean
#
#                                                                     GEE ID  \
# 4                                    users/bingosaucer/MODCF_interannualSD
# 5                                    users/bingosaucer/MODCF_intraannualSD
# 9                 users/bingosaucer/EarthEnvTopoMed_1stOrderPartialDerivEW
# 10                users/bingosaucer/EarthEnvTopoMed_1stOrderPartialDerivNS
# 11                users/bingosaucer/EarthEnvTopoMed_2ndOrderPartialDerivEW
# 12                users/bingosaucer/EarthEnvTopoMed_2ndOrderPartialDerivNS
# 13                          users/bingosaucer/EarthEnvTopoMed_AspectCosine
# 14                            users/bingosaucer/EarthEnvTopoMed_AspectSine
# 15                              users/bingosaucer/EarthEnvTopoMed_Eastness
# 16                             users/bingosaucer/EarthEnvTopoMed_Elevation
# 17                             users/bingosaucer/EarthEnvTopoMed_Northness
# 18                      users/bingosaucer/EarthEnvTopoMed_ProfileCurvature
# 19                             users/bingosaucer/EarthEnvTopoMed_Roughness
# 20                                 users/bingosaucer/EarthEnvTopoMed_Slope
# 21                   users/bingosaucer/EarthEnvTopoMed_TangentialCurvature
# 22                users/bingosaucer/EarthEnvTopoMed_TerrainRuggednessIndex
# 23                     users/bingosaucer/EarthEnvTopoMed_TopoPositionIndex
# 24               users/bingosaucer/EarthEnvTopoMed_VectorRuggednessMeasure
# 25               users/bingosaucer/FanEtAl_Depth_to_Water_Table_AnnualMean
# 27                                                      MODIS/006/MCD15A3H
# 28                                                       MODIS/006/MOD13Q1
# 29                       users/danvinci/ISRIC/SG_Absolute_depth_to_bedrock
# 30                              users/danvinci/ISRIC/SG_Bulk_density_000cm
# 31                              users/danvinci/ISRIC/SG_Bulk_density_005cm
# 32                              users/danvinci/ISRIC/SG_Bulk_density_015cm
# 33                              users/danvinci/ISRIC/SG_Bulk_density_030cm
# 34                              users/danvinci/ISRIC/SG_Bulk_density_060cm
# 35                              users/danvinci/ISRIC/SG_Bulk_density_100cm
# 36                              users/danvinci/ISRIC/SG_Bulk_density_200cm
# 37                                       users/danvinci/ISRIC/SG_CEC_000cm
# 38                                       users/danvinci/ISRIC/SG_CEC_005cm
# 39                                       users/danvinci/ISRIC/SG_CEC_015cm
# 40                                       users/danvinci/ISRIC/SG_CEC_030cm
# 41                                       users/danvinci/ISRIC/SG_CEC_060cm
# 42                                       users/danvinci/ISRIC/SG_CEC_100cm
# 43                                       users/danvinci/ISRIC/SG_CEC_200cm
# 44                              users/danvinci/ISRIC/SG_Clay_Content_000cm
# 45                              users/danvinci/ISRIC/SG_Clay_Content_005cm
# 46                              users/danvinci/ISRIC/SG_Clay_Content_015cm
# 47                              users/danvinci/ISRIC/SG_Clay_Content_030cm
# 48                              users/danvinci/ISRIC/SG_Clay_Content_060cm
# 49                              users/danvinci/ISRIC/SG_Clay_Content_100cm
# 50                              users/danvinci/ISRIC/SG_Clay_Content_200cm
# 51                          users/danvinci/ISRIC/SG_Coarse_fragments_000cm
# 52                          users/danvinci/ISRIC/SG_Coarse_fragments_005cm
# 53                          users/danvinci/ISRIC/SG_Coarse_fragments_015cm
# 54                          users/danvinci/ISRIC/SG_Coarse_fragments_030cm
# 55                          users/danvinci/ISRIC/SG_Coarse_fragments_060cm
# 56                          users/danvinci/ISRIC/SG_Coarse_fragments_100cm
# 57                          users/danvinci/ISRIC/SG_Coarse_fragments_200cm
# 58                                users/danvinci/ISRIC/SG_Depth_to_bedrock
# 59                              users/danvinci/ISRIC/SG_H2O_Capacity_000cm
# 60                              users/danvinci/ISRIC/SG_H2O_Capacity_005cm
# 61                              users/danvinci/ISRIC/SG_H2O_Capacity_015cm
# 62                              users/danvinci/ISRIC/SG_H2O_Capacity_030cm
# 63                              users/danvinci/ISRIC/SG_H2O_Capacity_060cm
# 64                              users/danvinci/ISRIC/SG_H2O_Capacity_100cm
# 65                              users/danvinci/ISRIC/SG_H2O_Capacity_200cm
# 66                users/danvinci/ISRIC/SG_Probability_occurrence_R_horizon
# 67                              users/danvinci/ISRIC/SG_Sand_Content_000cm
# 68                              users/danvinci/ISRIC/SG_Sand_Content_005cm
# 69                              users/danvinci/ISRIC/SG_Sand_Content_015cm
# 70                              users/danvinci/ISRIC/SG_Sand_Content_030cm
# 71                              users/danvinci/ISRIC/SG_Sand_Content_060cm
# 72                              users/danvinci/ISRIC/SG_Sand_Content_100cm
# 73                              users/danvinci/ISRIC/SG_Sand_Content_200cm
# 74                     users/danvinci/ISRIC/SG_Saturated_H2O_Content_000cm
# 75                     users/danvinci/ISRIC/SG_Saturated_H2O_Content_005cm
# 76                     users/danvinci/ISRIC/SG_Saturated_H2O_Content_015cm
# 77                     users/danvinci/ISRIC/SG_Saturated_H2O_Content_030cm
# 78                     users/danvinci/ISRIC/SG_Saturated_H2O_Content_060cm
# 79                     users/danvinci/ISRIC/SG_Saturated_H2O_Content_100cm
# 80                     users/danvinci/ISRIC/SG_Saturated_H2O_Content_200cm
# 81                              users/danvinci/ISRIC/SG_Silt_Content_000cm
# 82                              users/danvinci/ISRIC/SG_Silt_Content_005cm
# 83                              users/danvinci/ISRIC/SG_Silt_Content_015cm
# 84                              users/danvinci/ISRIC/SG_Silt_Content_030cm
# 85                              users/danvinci/ISRIC/SG_Silt_Content_060cm
# 86                              users/danvinci/ISRIC/SG_Silt_Content_100cm
# 87                              users/danvinci/ISRIC/SG_Silt_Content_200cm
# 88                               users/danvinci/ISRIC/SG_SOC_Content_000cm
# 89                               users/danvinci/ISRIC/SG_SOC_Content_005cm
# 90                               users/danvinci/ISRIC/SG_SOC_Content_015cm
# 91                               users/danvinci/ISRIC/SG_SOC_Content_030cm
# 92                               users/danvinci/ISRIC/SG_SOC_Content_060cm
# 93                               users/danvinci/ISRIC/SG_SOC_Content_100cm
# 94                               users/danvinci/ISRIC/SG_SOC_Content_200cm
# 95                               users/danvinci/ISRIC/SG_SOC_Density_000cm
# 96                               users/danvinci/ISRIC/SG_SOC_Density_005cm
# 97                               users/danvinci/ISRIC/SG_SOC_Density_015cm
# 98                               users/danvinci/ISRIC/SG_SOC_Density_030cm
# 99                               users/danvinci/ISRIC/SG_SOC_Density_060cm
# 100                              users/danvinci/ISRIC/SG_SOC_Density_100cm
# 101                              users/danvinci/ISRIC/SG_SOC_Density_200cm
# 102                       users/danvinci/ISRIC/SG_SOC_Stock_000cm_to_005cm
# 103                       users/danvinci/ISRIC/SG_SOC_Stock_005cm_to_015cm
# 104                       users/danvinci/ISRIC/SG_SOC_Stock_015cm_to_030cm
# 105                       users/danvinci/ISRIC/SG_SOC_Stock_030cm_to_060cm
# 106                       users/danvinci/ISRIC/SG_SOC_Stock_060cm_to_100cm
# 107                       users/danvinci/ISRIC/SG_SOC_Stock_100cm_to_200cm
# 108                  users/danvinci/ISRIC/SG_Soil_H2O_Capacity_pF_20_000cm
# 109                  users/danvinci/ISRIC/SG_Soil_H2O_Capacity_pF_20_005cm
# 110                  users/danvinci/ISRIC/SG_Soil_H2O_Capacity_pF_20_015cm
# 111                  users/danvinci/ISRIC/SG_Soil_H2O_Capacity_pF_20_030cm
# 112                  users/danvinci/ISRIC/SG_Soil_H2O_Capacity_pF_20_060cm
# 113                  users/danvinci/ISRIC/SG_Soil_H2O_Capacity_pF_20_100cm
# 114                  users/danvinci/ISRIC/SG_Soil_H2O_Capacity_pF_20_200cm
# 115                  users/danvinci/ISRIC/SG_Soil_H2O_Capacity_pF_23_000cm
# 116                  users/danvinci/ISRIC/SG_Soil_H2O_Capacity_pF_23_005cm
# 117                  users/danvinci/ISRIC/SG_Soil_H2O_Capacity_pF_23_015cm
# 118                  users/danvinci/ISRIC/SG_Soil_H2O_Capacity_pF_23_030cm
# 119                  users/danvinci/ISRIC/SG_Soil_H2O_Capacity_pF_23_060cm
# 120                  users/danvinci/ISRIC/SG_Soil_H2O_Capacity_pF_23_100cm
# 121                  users/danvinci/ISRIC/SG_Soil_H2O_Capacity_pF_23_200cm
# 122                  users/danvinci/ISRIC/SG_Soil_H2O_Capacity_pF_25_000cm
# 123                  users/danvinci/ISRIC/SG_Soil_H2O_Capacity_pF_25_005cm
# 124                  users/danvinci/ISRIC/SG_Soil_H2O_Capacity_pF_25_015cm
# 125                  users/danvinci/ISRIC/SG_Soil_H2O_Capacity_pF_25_030cm
# 126                  users/danvinci/ISRIC/SG_Soil_H2O_Capacity_pF_25_060cm
# 127                  users/danvinci/ISRIC/SG_Soil_H2O_Capacity_pF_25_100cm
# 128                  users/danvinci/ISRIC/SG_Soil_H2O_Capacity_pF_25_200cm
# 129                                              users/bingosaucer/HFP2009
# 130              users/danvinci/WC2/WorldClim2_BIO_Annual_Mean_Temperature
# 131                   users/danvinci/WC2/WorldClim2_BIO_Mean_Diurnal_Range
# 132                        users/danvinci/WC2/WorldClim2_BIO_Isothermality
# 133              users/danvinci/WC2/WorldClim2_BIO_Temperature_Seasonality
# 134     users/danvinci/WC2/WorldClim2_BIO_Max_Temperature_of_Warmest_Month
# 135     users/danvinci/WC2/WorldClim2_BIO_Min_Temperature_of_Coldest_Month
# 136             users/danvinci/WC2/WorldClim2_BIO_Temperature_Annual_Range
# 137  users/danvinci/WC2/WorldClim2_BIO_Mean_Temperature_of_Wettest_Quarter
# 138   users/danvinci/WC2/WorldClim2_BIO_Mean_Temperature_of_Driest_Quarter
# 139  users/danvinci/WC2/WorldClim2_BIO_Mean_Temperature_of_Warmest_Quarter
# 140  users/danvinci/WC2/WorldClim2_BIO_Mean_Temperature_of_Coldest_Quarter
# 141                 users/danvinci/WC2/WorldClim2_BIO_Annual_Precipitation
# 142       users/danvinci/WC2/WorldClim2_BIO_Precipitation_of_Wettest_Month
# 143        users/danvinci/WC2/WorldClim2_BIO_Precipitation_of_Driest_Month
# 144            users/danvinci/WC2/WorldClim2_BIO_Precipitation_Seasonality
# 145     users/danvinci/WC2/WorldClim2_BIO_Precipitation_of_Wettest_Quarter
# 146      users/danvinci/WC2/WorldClim2_BIO_Precipitation_of_Driest_Quarter
# 147     users/danvinci/WC2/WorldClim2_BIO_Precipitation_of_Warmest_Quarter
# 148     users/danvinci/WC2/WorldClim2_BIO_Precipitation_of_Coldest_Quarter
# 149              users/danvinci/WC2/WorldClim2_H2OVaporPressure_AnnualMean
# 150                users/danvinci/WC2/WorldClim2_SolarRadiation_AnnualMean
# 151                     users/danvinci/WC2/WorldClim2_WindSpeed_AnnualMean
#
#                                                                                                               Description
# 4                     Mean between-year seasonality represented as the mean of the 2000-2014 monthly standard deviations;
# 5              Within-year seasonality represented as the standard deviation of mean 2000-2014 monthly cloud frequencies;
# 9                           1st Order Partial Derivative of the Elevation (with reference to the East-West / X direction)
# 10                        1st Order Partial Derivative of the Elevation (with reference to the North-South / Y direction)
# 11                          2nd Order Partial Derivative of the Elevation (with reference to the East-West / X direction)
# 12                        2nd Order Partial Derivative of the Elevation (with reference to the North-South / Y direction)
# 13                                                                                                          Aspect Cosine
# 14                                                                                                            Aspect Sine
# 15                                                                                                               Eastness
# 16                                                                                                  Elevation (in meters)
# 17                                                                                                              Northness
# 18                                                       Profile Curvature (a more specific measure of topographic slope)
# 19                                                                                                              Roughness
# 20                                                                                                                  Slope
# 21                                                                                                   Tangential Curvature
# 22                                                                                               Terrain Ruggedness Index
# 23                                                                                             Topographic Position Index
# 24                                                                                              Vector Ruggedness Measure
# 25                         Mean annual depth of the water table on the terrestrial land surface (in m below land surface)
# 27                                                        Leaf Area Index (LAI) = MCD15A3H.006 Terra+Aqua Leaf Area Index
# 28                                                        MYD13Q1.006 Vegetation Indices 16-Day Global 250m: NDVI and EVI
# 29                                                                       BDTICM_M_250m_ll_b1 = Abslolute Depth to Bedrock
# 30                                                                 BLDFIE_M_sl1_250m_ll = Bulk density (fine earth) 0.00m
# 31                                                              BLDFIE_M_sl2_250m_ll = Bulk density (fine earth) at 0.05m
# 32                                                              BLDFIE_M_sl3_250m_ll = Bulk density (fine earth) at 0.15m
# 33                                                              BLDFIE_M_sl4_250m_ll = Bulk density (fine earth) at 0.30m
# 34                                                              BLDFIE_M_sl5_250m_ll = Bulk density (fine earth) at 0.60m
# 35                                                              BLDFIE_M_sl6_250m_ll = Bulk density (fine earth) at 1.00m
# 36                                                              BLDFIE_M_sl7_250m_ll = Bulk density (fine earth) at 2.00m
# 37                                                       CECSOL_M_sl1_250m_ll = Cation exchange capacity of soil at 0.00m
# 38                                                       CECSOL_M_sl2_250m_ll = Cation exchange capacity of soil at 0.05m
# 39                                                       CECSOL_M_sl3_250m_ll = Cation exchange capacity of soil at 0.15m
# 40                                                       CECSOL_M_sl4_250m_ll = Cation exchange capacity of soil at 0.30m
# 41                                                       CECSOL_M_sl5_250m_ll = Cation exchange capacity of soil at 0.60m
# 42                                                       CECSOL_M_sl6_250m_ll = Cation exchange capacity of soil at 1.00m
# 43                                                       CECSOL_M_sl7_250m_ll = Cation exchange capacity of soil at 2.00m
# 44                                                         CLYPPT_M_sl1_250m_ll = Clay content (0–2 micro meter) at 0.00m
# 45                                                          CLYPPT_M_sl2_250m_ll= Clay content (0–2 micro meter) at 0.05m
# 46                                                          CLYPPT_M_sl3_250m_ll= Clay content (0–2 micro meter) at 0.15m
# 47                                                          CLYPPT_M_sl4_250m_ll= Clay content (0–2 micro meter) at 0.30m
# 48                                                          CLYPPT_M_sl5_250m_ll= Clay content (0–2 micro meter) at 0.60m
# 49                                                          CLYPPT_M_sl6_250m_ll= Clay content (0–2 micro meter) at 1.00m
# 50                                                          CLYPPT_M_sl7_250m_ll= Clay content (0–2 micro meter) at 2.00m
# 51                                                            CRFVOL_M_sl1_250m_ll = Coarse fragments volumetric at 0.00m
# 52                                                            CRFVOL_M_sl2_250m_ll = Coarse fragments volumetric at 0.05m
# 53                                                            CRFVOL_M_sl3_250m_ll = Coarse fragments volumetric at 0.15m
# 54                                                            CRFVOL_M_sl4_250m_ll = Coarse fragments volumetric at 0.30m
# 55                                                            CRFVOL_M_sl5_250m_ll = Coarse fragments volumetric at 0.60m
# 56                                                            CRFVOL_M_sl6_250m_ll = Coarse fragments volumetric at 1.00m
# 57                                                            CRFVOL_M_sl7_250m_ll = Coarse fragments volumetric at 2.00m
# 58                                                                   BDRICM_M_250m_ll_b1 = Depth to Bedrock (up to 200cm)
# 59     WWP_M_sl1_250m_ll = Derived available soil water capacity (volumetric fraction) until wilting point for depth 0 cm
# 60     WWP_M_sl2_250m_ll = Derived available soil water capacity (volumetric fraction) until wilting point for depth 5 cm
# 61    WWP_M_sl3_250m_ll = Derived available soil water capacity (volumetric fraction) until wilting point for depth 15 cm
# 62    WWP_M_sl4_250m_ll = Derived available soil water capacity (volumetric fraction) until wilting point for depth 30 cm
# 63    WWP_M_sl5_250m_ll = Derived available soil water capacity (volumetric fraction) until wilting point for depth 60 cm
# 64   WWP_M_sl6_250m_ll = Derived available soil water capacity (volumetric fraction) until wilting point for depth 100 cm
# 65   WWP_M_sl7_250m_ll = Derived available soil water capacity (volumetric fraction) until wilting point for depth 200 cm
# 66                                        BDRLOG_M_250m_ll = Predicted Probability of Occurence (0-100%) in the R Horizon
# 67                                                     SNDPPT_M_sl1_250m_ll = Sand content (50–2000 micro meter) at 0.00m
# 68                                                     SNDPPT_M_sl2_250m_ll = Sand content (50–2000 micro meter) at 0.05m
# 69                                                     SNDPPT_M_sl3_250m_ll = Sand content (50–2000 micro meter) at 0.15m
# 70                                                     SNDPPT_M_sl4_250m_ll = Sand content (50–2000 micro meter) at 0.30m
# 71                                                     SNDPPT_M_sl5_250m_ll = Sand content (50–2000 micro meter) at 0.60m
# 72                                                     SNDPPT_M_sl6_250m_ll = Sand content (50–2000 micro meter) at 1.00m
# 73                                                     SNDPPT_M_sl7_250m_ll = Sand content (50–2000 micro meter) at 2.00m
# 74                      AWCtS_M_sl1_250m_ll = Derived saturated water content (volumetric fraction) teta-S for depth 0 cm
# 75                      AWCtS_M_sl2_250m_ll = Derived saturated water content (volumetric fraction) teta-S for depth 5 cm
# 76                     AWCtS_M_sl3_250m_ll = Derived saturated water content (volumetric fraction) teta-S for depth 15 cm
# 77                     AWCtS_M_sl4_250m_ll = Derived saturated water content (volumetric fraction) teta-S for depth 30 cm
# 78                     AWCtS_M_sl5_250m_ll = Derived saturated water content (volumetric fraction) teta-S for depth 60 cm
# 79                    AWCtS_M_sl6_250m_ll = Derived saturated water content (volumetric fraction) teta-S for depth 100 cm
# 80                    AWCtS_M_sl7_250m_ll = Derived saturated water content (volumetric fraction) teta-S for depth 200 cm
# 81                                                        SLTPPT_M_sl1_250m_ll = Silt content (2–50 micro meter) at 0.00m
# 82                                                        SLTPPT_M_sl2_250m_ll = Silt content (2–50 micro meter) at 0.05m
# 83                                                        SLTPPT_M_sl3_250m_ll = Silt content (2–50 micro meter) at 0.15m
# 84                                                        SLTPPT_M_sl4_250m_ll = Silt content (2–50 micro meter) at 0.30m
# 85                                                        SLTPPT_M_sl5_250m_ll = Silt content (2–50 micro meter) at 0.60m
# 86                                                        SLTPPT_M_sl6_250m_ll = Silt content (2–50 micro meter) at 1.00m
# 87                                                        SLTPPT_M_sl7_250m_ll = Silt content (2–50 micro meter) at 2.00m
# 88                                      ORCDRC_M_sl1_250m_ll = Soil organic carbon content (fine earth fraction) at 0.00m
# 89                                      ORCDRC_M_sl2_250m_ll = Soil organic carbon content (fine earth fraction) at 0.05m
# 90                                      ORCDRC_M_sl3_250m_ll = Soil organic carbon content (fine earth fraction) at 0.15m
# 91                                      ORCDRC_M_sl4_250m_ll = Soil organic carbon content (fine earth fraction) at 0.30m
# 92                                      ORCDRC_M_sl5_250m_ll = Soil organic carbon content (fine earth fraction) at 0.60m
# 93                                      ORCDRC_M_sl6_250m_ll = Soil organic carbon content (fine earth fraction) at 1.00m
# 94                                      ORCDRC_M_sl7_250m_ll = Soil organic carbon content (fine earth fraction) at 2.00m
# 95                                   OCDENS_M_sl1_250m_ll = Soil organic carbon density in kg per cubic-m at depth 0.00 m
# 96                                   OCDENS_M_sl2_250m_ll = Soil organic carbon density in kg per cubic-m at depth 0.05 m
# 97                                   OCDENS_M_sl3_250m_ll = Soil organic carbon density in kg per cubic-m at depth 0.15 m
# 98                                   OCDENS_M_sl4_250m_ll = Soil organic carbon density in kg per cubic-m at depth 0.30 m
# 99                                   OCDENS_M_sl5_250m_ll = Soil organic carbon density in kg per cubic-m at depth 0.60 m
# 100                                  OCDENS_M_sl6_250m_ll = Soil organic carbon density in kg per cubic-m at depth 1.00 m
# 101                                  OCDENS_M_sl7_250m_ll = Soil organic carbon density in kg per cubic-m at depth 2.00 m
# 102                                                     OCSTHA_M_sd1_250m_ll = Soil Organic Carbon Stock from 0.00m-0.05m
# 103                                                     OCSTHA_M_sd2_250m_ll = Soil Organic Carbon Stock from 0.05m-0.15m
# 104                                                     OCSTHA_M_sd3_250m_ll = Soil Organic Carbon Stock from 0.15m-0.30m
# 105                                                     OCSTHA_M_sd4_250m_ll = Soil Organic Carbon Stock from 0.30m-0.60m
# 106                                                     OCSTHA_M_sd5_250m_ll = Soil Organic Carbon Stock from 0.60m-1.00m
# 107                                                        OCSTHA_M_sd6_250m = Soil Organic Carbon Stock from 1.00m-2.00m
# 108     AWCh1_M_sl1_250m_ll = Derived available soil water capacity (volumetric fraction) with FC = pF 2.0 for depth 0 cm
# 109     AWCh1_M_sl2_250m_ll = Derived available soil water capacity (volumetric fraction) with FC = pF 2.0 for depth 5 cm
# 110     AWCh1_M_sl3_250m_ll = Derived available soil water capacity (volumetric fraction) with FC = pF 2.0 for depth 5 cm
# 111    AWCh1_M_sl4_250m_ll = Derived available soil water capacity (volumetric fraction) with FC = pF 2.0 for depth 30 cm
# 112    AWCh1_M_sl5_250m_ll = Derived available soil water capacity (volumetric fraction) with FC = pF 2.0 for depth 60 cm
# 113   AWCh1_M_sl6_250m_ll = Derived available soil water capacity (volumetric fraction) with FC = pF 2.0 for depth 100 cm
# 114   AWCh1_M_sl7_250m_ll = Derived available soil water capacity (volumetric fraction) with FC = pF 2.0 for depth 200 cm
# 115     AWCh2_M_sl1_250m_ll = Derived available soil water capacity (volumetric fraction) with FC = pF 2.3 for depth 0 cm
# 116     AWCh2_M_sl2_250m_ll = Derived available soil water capacity (volumetric fraction) with FC = pF 2.3 for depth 5 cm
# 117    AWCh2_M_sl3_250m_ll = Derived available soil water capacity (volumetric fraction) with FC = pF 2.3 for depth 15 cm
# 118    AWCh2_M_sl4_250m_ll = Derived available soil water capacity (volumetric fraction) with FC = pF 2.3 for depth 30 cm
# 119    AWCh2_M_sl5_250m_ll = Derived available soil water capacity (volumetric fraction) with FC = pF 2.3 for depth 60 cm
# 120   AWCh2_M_sl6_250m_ll = Derived available soil water capacity (volumetric fraction) with FC = pF 2.3 for depth 100 cm
# 121   AWCh2_M_sl7_250m_ll = Derived available soil water capacity (volumetric fraction) with FC = pF 2.3 for depth 200 cm
# 122     AWCh3_M_sl1_250m_ll = Derived available soil water capacity (volumetric fraction) with FC = pF 2.5 for depth 0 cm
# 123     AWCh3_M_sl2_250m_ll = Derived available soil water capacity (volumetric fraction) with FC = pF 2.5 for depth 5 cm
# 124    AWCh3_M_sl3_250m_ll = Derived available soil water capacity (volumetric fraction) with FC = pF 2.5 for depth 15 cm
# 125    AWCh3_M_sl4_250m_ll = Derived available soil water capacity (volumetric fraction) with FC = pF 2.5 for depth 30 cm
# 126    AWCh3_M_sl5_250m_ll = Derived available soil water capacity (volumetric fraction) with FC = pF 2.5 for depth 60 cm
# 127   AWCh3_M_sl6_250m_ll = Derived available soil water capacity (volumetric fraction) with FC = pF 2.5 for depth 100 cm
# 128   AWCh3_M_sl7_250m_ll = Derived available soil water capacity (volumetric fraction) with FC = pF 2.5 for depth 200 cm
# 129                                                                                                  Human Footprint 2009
# 130                                                                                WC01 / BIO01 = Annual Mean Temperature
# 131                                             WC02 / BIO02 = Mean Diurnal Range (Mean of monthly (max temp - min temp))
# 132                                                                      WC03 / BIO03 = Isothermality (BIO2/BIO7) (* 100)
# 133                                                      WC04 / BIO04 = Temperature Seasonality (standard deviation *100)
# 134                                                                       WC05 / BIO05 = Max Temperature of Warmest Month
# 135                                                                       WC06 / BIO06 = Min Temperature of Coldest Month
# 136                                                                   WC07 / BIO07 = Temperature Annual Range (BIO5-BIO6)
# 137                                                                    WC08 / BIO08 = Mean Temperature of Wettest Quarter
# 138                                                                     WC09 / BIO09 = Mean Temperature of Driest Quarter
# 139                                                                    WC10 / BIO10 = Mean Temperature of Warmest Quarter
# 140                                                                    WC11 / BIO11 = Mean Temperature of Coldest Quarter
# 141                                                                                   WC12 / BIO12 = Annual Precipitation
# 142                                                                         WC13 / BIO13 = Precipitation of Wettest Month
# 143                                                                          WC14 / BIO14 = Precipitation of Driest Month
# 144                                                   WC15 / BIO15 = Precipitation Seasonality (Coefficient of Variation)
# 145                                                                       WC16 / BIO16 = Precipitation of Wettest Quarter
# 146                                                                        WC17 / BIO17 = Precipitation of Driest Quarter
# 147                                                                       WC18 / BIO18 = Precipitation of Warmest Quarter
# 148                                                                       WC19 / BIO19 = Precipitation of Coldest Quarter
# 149            Annual mean of the water vapor pressure as calculated using individual month layers for H2O vapor pressure
# 150                    Annual mean of the solar radiation as calculated using individual month layers for solar radiation
# 151                              Annual mean of the wind speed as calculated using individual month layers for wind speed

# %% [markdown]
# Not yet available

# %%
ENCOV[ENCOV['GEE ID'].isnull()]
# Out:
#         #                                            Variable  \
# 0     1.0                                 CGIAR_Aridity_Index
# 1     2.0                                           CGIAR_PET
# 2     3.0     ConsensusLandCover_Human_Development_Percentage
# 3     4.0                       CSP_Global_Human_Modification
# 6     7.0                 EarthEnvCloudCover_MODCF_meanannual
# 7     8.0  EarthEnvCloudCover_MODCF_seasonality_concentration
# 8     9.0          EarthEnvCloudCover_MODCF_seasonality_theta
# 26   27.0                            GPWv4_Population_Density
# 152   NaN                                                 NaN
# 153   NaN                                                 NaN
#
#                                                                                                                                                                                                                      Description  \
# 0                                                                                                                                                                                                      Global AI (Aridity Index)
# 1                                                                                                                                                                                      Global PET (Potential Evapotranspiration)
# 2                                                                                                                       Percentage of urban/built-up areas summed with cultivated/managed vegetation (summed via composite code)
# 3                                                                The global Human Modification dataset (gHM) provides a cumulative measure of human modification of terrestrial lands globally at 1 square-kilometer resolution.
# 6                                                                                                                                                                                Mean annual cloud frequency (%) over 2000-2014;
# 7                                                           Seasonal cloud concentration index (see methods for full description) ranging from 0 (all months equally cloudy) to 100 (all clouds are observed in a single month);
# 8    Timing of peak seasonal cloud concentration (see methods for full description) expressed as an angle (degrees) ranging from 0 (peak cloudiness observed on January 1st) to 360 (peak cloudiness observed on December 31st).
# 26                                                                                                                                            Gridded Population of the World, Version 4 (GPWv4): UN-Adjusted Population Density
# 152                                                                                                                                                                                                                          NaN
# 153                                                                                                                                                                                                                          NaN
#
#                                                                                           Source / Link  \
# 0                                         http://www.cgiar-csi.org/data/global-aridity-and-pet-database
# 1                                         http://www.cgiar-csi.org/data/global-aridity-and-pet-database
# 2                                                                    https://www.earthenv.org/landcover
# 3            https://developers.google.com/earth-engine/datasets/catalog/CSP_HM_GlobalHumanModification
# 6                                                  https://data.earthenv.org/cloud/MODCF_meanannual.tif
# 7                                   https://data.earthenv.org/cloud/MODCF_seasonality_concentration.tif
# 8                                           https://data.earthenv.org/cloud/MODCF_seasonality_theta.tif
# 26   https://explorer.earthengine.google.com/#detail/CIESIN%2FGPWv4%2Funwpp-adjusted-population-density
# 152                                                                                                 NaN
# 153                                                                                                 NaN
#
#                                doi  File Size (GB) GEE ID Unnamed: 7 filename
# 0       10.1016/j.agee.2008.01.014             NaN    NaN        NaN      NaN
# 1       10.1016/j.agee.2008.01.014             NaN    NaN        NaN      NaN
# 2                10.1111/geb.12182             NaN    NaN        NaN      NaN
# 3                10.1111/gcb.14549             NaN    NaN        NaN      NaN
# 6    10.1371/journal. pbio.1002415            0.67    NaN        NaN      NaN
# 7    10.1371/journal. pbio.1002415            0.67    NaN        NaN      NaN
# 8    10.1371/journal. pbio.1002415            0.67    NaN        NaN      NaN
# 26                10.7927/H4HX19NJ             NaN    NaN        NaN      NaN
# 152                            NaN             NaN    NaN        NaN      NaN
# 153                            NaN          264.05    NaN        NaN      NaN

# %% [markdown]
# # Reference

# %% [markdown]
# Reading GeoTIFF:
# - http://xarray.pydata.org/en/stable/io.html#rasterio
# - http://xarray.pydata.org/en/stable/generated/xarray.open_rasterio.html#xarray-open-rasterio
